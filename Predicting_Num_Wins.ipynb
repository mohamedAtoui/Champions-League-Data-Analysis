# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataY=pd.read_excel(r"Data\teams_wins_21_22_2.xlsx")
dataY= dataY.sort_values(by='Team', ascending=True)
dataY
# Out:
#                     Team  Wins
# 4                   Ajax     7
# 19              Atalanta     4
# 3               Atlético     5
# 26             Barcelona     3
# 8          Bayern Munich     9
# 9                Benfica     7
# 30              Besiktas     0
# 21     Borussia Dortmund     3
# 14               Chelsea     8
# 28           Club Brugge     2
# 27           Dynamo Kyiv     1
# 7            Inter Milan     5
# 15              Juventus     6
# 18               Leipzig     3
# 12                 Lille     5
# 2              Liverpool    10
# 31                 Malmo     1
# 0              Man. City     9
# 10     Manchester United     5
# 25                 Milan     2
# 1                  Paris     6
# 24                 Porto     3
# 6            Real Madrid     9
# 13              Salzburg     3
# 16               Sevilla     4
# 23      Shakhtar Donetsk     2
# 22      Sheriff Tiraspol     3
# 5            Sporting CP     3
# 11            Villarreal     8
# ...

# %%
data=pd.read_csv(r"C:\Users\i7 11Th\Desktop\Python2Proj\final_data.csv")
data1=[]
data1=pd.DataFrame(data1)
data1['club']=data['club']

data1['def']=data['scaled_performance_def']
data1['gk']=data['scaled_Scorekeeping']
data1['mid']=data['mid_performance']
data1['att']=data['att_performance']
data1['on_target_per_game']=data['scaled_on_target']
data1['assists_dribble']=data['scaled_Assist_dribble_per_match']
data1


#data1['num_wins']=dataY['Wins']
# Out:
#                 club     def      gk    mid    att  on_target_per_game  \
# 0               Ajax   44.50   18.69  57.98  61.01                0.00
# 1           Atalanta   76.15   24.12  55.06  44.50               12.38
# 2           Atlético   53.72   49.95  52.52  56.10               12.38
# 3          Barcelona   52.24   32.43  52.86  57.40               15.57
# 4             Bayern   43.64   54.10  58.44  56.17               24.95
# 5            Benfica   69.76   74.39  49.50  51.38               28.14
# 6           Beşiktaş   88.51   19.12  59.09  43.24               28.14
# 7            Chelsea   60.30   15.60  64.54  63.08               29.64
# 8        Club Brugge   35.03   15.28  63.87  47.77               40.53
# 9           Dortmund    0.00   39.99  59.81  43.88               43.71
# 10       Dynamo Kyiv   33.50   56.98  51.04  38.40               48.41
# 11             Inter   73.63   32.06  66.95  48.72               49.91
# ...
